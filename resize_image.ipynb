# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
import numpy as np
import cv2 as cv
img = cv.imread('G0010769.jpg', cv.COLOR_BGR2RGB)
res = cv.resize(img,None,fx=2, fy=2, interpolation = cv.INTER_CUBIC)
# #OR
# height, width = img.shape[:2]
res = cv.resize(img,(640, 480), interpolation = cv.INTER_CUBIC)

# %%
cv.imshow('img',img)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
cv.imwrite('name.jpg',img)
# Out:
# True

# %%
import glob
image_list = []
for filename in glob.glob(r'C:\Users\mayan\Desktop\Dataset 1 (Simplex)\Train data\Positive data/*.JPG'):
    img = cv.imread(filename)
    print(filename)
    res = cv.resize(img,(640, 480), interpolation = cv.INTER_CUBIC)
    adr=r'C:\Users\mayan\pothole_detection\images\train\pos/' + filename[-12:]
    cv.imwrite(adr,res) 
    image_list.append(res)
# Out:
# C:\Users\mayan\Desktop\Dataset 1 (Simplex)\Train data\Positive data\G0010033.JPG
# C:\Users\mayan\Desktop\Dataset 1 (Simplex)\Train data\Positive data\G0010034.JPG
# C:\Users\mayan\Desktop\Dataset 1 (Simplex)\Train data\Positive data\G0010035.JPG
# C:\Users\mayan\Desktop\Dataset 1 (Simplex)\Train data\Positive data\G0010036.JPG
# C:\Users\mayan\Desktop\Dataset 1 (Simplex)\Train data\Positive data\G0010037.JPG
# C:\Users\mayan\Desktop\Dataset 1 (Simplex)\Train data\Positive data\G0010109.JPG
# C:\Users\mayan\Desktop\Dataset 1 (Simplex)\Train data\Positive data\G0010110.JPG
# C:\Users\mayan\Desktop\Dataset 1 (Simplex)\Train data\Positive data\G0010111.JPG
# C:\Users\mayan\Desktop\Dataset 1 (Simplex)\Train data\Positive data\G0010112.JPG
# C:\Users\mayan\Desktop\Dataset 1 (Simplex)\Train data\Positive data\G0010113.JPG
# C:\Users\mayan\Desktop\Dataset 1 (Simplex)\Train data\Positive data\G0010114.JPG
# C:\Users\mayan\Desktop\Dataset 1 (Simplex)\Train data\Positive data\G0010115.JPG
# ...

# %%
import glob
image_list = []
for filename in glob.glob(r'C:\Users\mayan\Desktop\Dataset 1 (Simplex)\Train data\Negative data/*.JPG'):
    img = cv.imread(filename)
    print(filename)
    res = cv.resize(img,(640, 480), interpolation = cv.INTER_CUBIC)
    adr=r'C:\Users\mayan\pothole_detection\images\train\neg/' + filename[-12:]
    cv.imwrite(adr,res) 
    image_list.append(res)
# Out:
# C:\Users\mayan\Desktop\Dataset 1 (Simplex)\Train data\Negative data\G0015965.JPG
# C:\Users\mayan\Desktop\Dataset 1 (Simplex)\Train data\Negative data\G0016163.JPG
# C:\Users\mayan\Desktop\Dataset 1 (Simplex)\Train data\Negative data\G0016169.JPG
# C:\Users\mayan\Desktop\Dataset 1 (Simplex)\Train data\Negative data\G0016180.JPG
# C:\Users\mayan\Desktop\Dataset 1 (Simplex)\Train data\Negative data\G0016204.JPG
# C:\Users\mayan\Desktop\Dataset 1 (Simplex)\Train data\Negative data\G0016209.JPG
# C:\Users\mayan\Desktop\Dataset 1 (Simplex)\Train data\Negative data\G0016210.JPG
# C:\Users\mayan\Desktop\Dataset 1 (Simplex)\Train data\Negative data\G0016216.JPG
# C:\Users\mayan\Desktop\Dataset 1 (Simplex)\Train data\Negative data\G0016229.JPG
# C:\Users\mayan\Desktop\Dataset 1 (Simplex)\Train data\Negative data\G0016240.JPG
# C:\Users\mayan\Desktop\Dataset 1 (Simplex)\Train data\Negative data\G0016241.JPG
# C:\Users\mayan\Desktop\Dataset 1 (Simplex)\Train data\Negative data\G0016297.JPG
# ...

# %%
# import glob
# image_list = []
# for filename in glob.glob(r'C:\Users\mayan\Desktop\Dataset 1 (Simplex)\Train data\Negative data/*.JPG'):
#     img = cv.imread(filename)
#     print(filename)
#     res = cv.resize(img,(640, 480), interpolation = cv.INTER_CUBIC)
#     adr=r'C:\Users\mayan\pothole_detection\images\train\neg/' + filename[-12:]
#     cv.imwrite(adr,res) 
#     image_list.append(res)

# %%
import glob
image_list = []
for filename in glob.glob(r'C:\Users\mayan\Desktop\Dataset 1 (Simplex)\Test data/*.JPG'):
    img = cv.imread(filename)
    print(filename)
    res = cv.resize(img,(640, 480), interpolation = cv.INTER_CUBIC)
    adr=r'C:\Users\mayan\pothole_detection\images\test/' + filename[-12:]
    cv.imwrite(adr,res) 
    image_list.append(res)
# Out:
# C:\Users\mayan\Desktop\Dataset 1 (Simplex)\Test data\G0011476.JPG
# C:\Users\mayan\Desktop\Dataset 1 (Simplex)\Test data\G0011523.JPG
# C:\Users\mayan\Desktop\Dataset 1 (Simplex)\Test data\G0011524.JPG
# C:\Users\mayan\Desktop\Dataset 1 (Simplex)\Test data\G0011562.JPG
# C:\Users\mayan\Desktop\Dataset 1 (Simplex)\Test data\G0011585.JPG
# C:\Users\mayan\Desktop\Dataset 1 (Simplex)\Test data\G0011587.JPG
# C:\Users\mayan\Desktop\Dataset 1 (Simplex)\Test data\G0011601.JPG
# C:\Users\mayan\Desktop\Dataset 1 (Simplex)\Test data\G0011602.JPG
# C:\Users\mayan\Desktop\Dataset 1 (Simplex)\Test data\G0011603.JPG
# C:\Users\mayan\Desktop\Dataset 1 (Simplex)\Test data\G0011614.JPG
# C:\Users\mayan\Desktop\Dataset 1 (Simplex)\Test data\G0011616.JPG
# C:\Users\mayan\Desktop\Dataset 1 (Simplex)\Test data\G0011661.JPG
# C:\Users\mayan\Desktop\Dataset 1 (Simplex)\Test data\G0011662.JPG
# C:\Users\mayan\Desktop\Dataset 1 (Simplex)\Test data\G0011664.JPG
# ...

# %%
cv.imwrite('name.jpg',image_list[0])
# Out:
# True

# %%
cv.imshow('image',image_list[0])
cv.waitKey(0)
cv.destroyAllWindows()
